# %% [markdown]
# 1. Когда используется критерий Стьюдента, а когда Z –критерий?

# %% [markdown]
# Стьюдент-критерий — это проверка статистической гипотезы, используемая для сравнения средних значений двух групп, когда размер выборки невелик или дисперсия совокупности неизвестна, тогда как z-критерий используется, когда размер выборки велик и известна дисперсия совокупности.

# %% [markdown]
# 2. Проведите тест гипотезы. Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр оказался равным 17.5 мм, а дисперсия известна и равна 4 кв. мм.

# %% [markdown]
# Нулевая гипотеза H0: u = 17. Альтернативная гипотеза Н1: u > 17.
# U = (17.5-17)/sqrt(4)*sqrt(100) = 2.5
# Критическая область 1-0,05/2 = +-1.96 Для данного значения статистики в таблице уровня значимости соответствует критическое значение Z=1.645.
# 2.5>1.645 поэтому отклоняем нулевую гипотезу и принимаем альтернативную.

# %% [markdown]
# 3. Продавец утверждает, что средний вес пачки печенья составляет 200 г.
# Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
# Известно, что их веса распределены нормально.
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%? (Провести двусторонний тест.)

# %%
import numpy as np
import scipy.stats as stats
weights = np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])

mean = weights.mean()
std = weights.std(ddof=1)
t = (mean-200)/(std/np.sqrt(10))
t
# Out:
# -1.0651074037450896

# %% [markdown]
# Доверительная вероятность 99%.
# Число степеней свободы 10-1=9.
# По таблице Стьюдента находим критическое 3,25 .
# Значение не попадает в критическую область, таким образом гипотезу не отвергаем.

# %% [markdown]
# 4. Есть ли статистически значимые различия в росте дочерей?
# Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169
# Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160

# %%
mothers = [172, 177, 158, 170, 178, 175, 164, 160, 169, 165]
daughters = [173, 175, 162, 174, 175, 168, 155, 170, 160, 163]

stats.ttest_rel(mothers, daughters)
# Out:
# TtestResult(statistic=0.6648478531431979, pvalue=0.5228168632983574, df=9)

# %% [markdown]
# Т.к. pvalue > 0.05, статистически заничмых различий нет.
